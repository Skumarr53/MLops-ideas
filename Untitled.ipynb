# %%
import os

# %%
os.chdir("/home/skumar/DaatScience/MLflow_testing")

# %%
os.getcwd()
# Out:
# '/home/skumar/DaatScience/MLflow_testing'

# %%
# !python --version
# Out:
# Python 3.8.20

# %%
# %pip install loguru==0.7.2
# %pip install hydra-core==1.3
# %pip install python-dotenv==1.0.1
# %pip install numpy==1.24.4
# %pip install cryptography==43.0.1
# %pip install gensim==4.3.3
# %pip install cython==3.0.11
# %pip install spacy==3.4.4 #3.0.4
# %pip install thinc==8.1.7
# %pip install pandas==2.0.0
# %pip install snowflake-connector-python==3.12.2
# %pip install transformers==4.46.1
# %pip install pyarrow==16.0.0
# %pip install datasets==3.1.0
# %pip install evaluate==0.4.3
# %pip install pyspark==3.5.3
# %pip install dask==2023.10.1 
# %pip install distributed==2023.10.1
# %pip install torch==2.0.0
# %pip install cymem==2.0.8
# %pip install scikit-learn==1.1.0
# %pip install typer==0.7.0
# %pip install accelerate==0.26.0
# Out:
# Requirement already satisfied: loguru==0.7.2 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (0.7.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting hydra-core==1.3
#   Downloading hydra_core-1.3.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: omegaconf~=2.2 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from hydra-core==1.3) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from hydra-core==1.3) (4.9.3)
# Requirement already satisfied: packaging in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from hydra-core==1.3) (24.2)
# Requirement already satisfied: importlib-resources in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from hydra-core==1.3) (6.4.5)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from omegaconf~=2.2->hydra-core==1.3) (6.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from importlib-resources->hydra-core==1.3) (3.20.2)
# Downloading hydra_core-1.3.0-py3-none-any.whl (153 kB)
# Installing collected packages: hydra-core
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.3.2
#     Uninstalling hydra-core-1.3.2:
#       Successfully uninstalled hydra-core-1.3.2
# Successfully installed hydra-core-1.3.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv==1.0.1 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy==1.24.4 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (1.24.4)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting cryptography==43.0.1
#   Downloading cryptography-43.0.1-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from cryptography==43.0.1) (1.17.1)
# Requirement already satisfied: pycparser in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from cffi>=1.12->cryptography==43.0.1) (2.22)
# Downloading cryptography-43.0.1-cp37-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 6.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: cryptography
# Successfully installed cryptography-43.0.1
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting gensim==4.3.3
#   Downloading gensim-4.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from gensim==4.3.3) (1.24.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from gensim==4.3.3) (1.9.3)
# Collecting smart-open>=1.8.1 (from gensim==4.3.3)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from smart-open>=1.8.1->gensim==4.3.3) (1.17.0)
# Downloading gensim-4.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 10.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.3.3 smart-open-7.1.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting cython==3.0.11
#   Downloading Cython-3.0.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Downloading Cython-3.0.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 51.4 MB/s eta 0:00:00
# Installing collected packages: cython
# Successfully installed cython-3.0.11
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting spacy==3.4.4
#   Downloading spacy-3.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.10 (from spacy==3.4.4)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy==3.4.4)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.4.4)
#   Downloading murmurhash-1.0.12.tar.gz (13 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.4.4)
#   Downloading cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.4.4)
#   Downloading preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.2.0,>=8.1.0 (from spacy==3.4.4)
#   Downloading thinc-8.1.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.1.0,>=0.9.1 (from spacy==3.4.4)
#   Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy==3.4.4)
#   Downloading srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy==3.4.4)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting typer<0.8.0,>=0.3.0 (from spacy==3.4.4)
#   Downloading typer-0.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting pathy>=0.3.5 (from spacy==3.4.4)
#   Downloading pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy==3.4.4)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy==3.4.4)
#   Downloading pydantic-1.10.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (153 kB)
# Requirement already satisfied: jinja2 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (3.1.4)
# Requirement already satisfied: setuptools in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (75.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from spacy==3.4.4) (24.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy==3.4.4)
#   Downloading langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy==3.4.4)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.3.5->spacy==3.4.4)
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.4.4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.4) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.4) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.4) (2024.8.30)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.2.0,>=8.1.0->spacy==3.4.4)
#   Downloading blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.2.0,>=8.1.0->spacy==3.4.4)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy==3.4.4) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from jinja2->spacy==3.4.4) (2.1.5)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.4.4)
#   Downloading marisa_trie-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Downloading spacy-3.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 45.9 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
# Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
# Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Downloading preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
# Downloading pydantic-1.10.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.6 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
# Downloading thinc-8.1.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (931 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.7/931.7 kB 13.2 MB/s eta 0:00:00
# Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Downloading blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 26.2 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 6.6 MB/s eta 0:00:007.0 MB/s eta 0:00:01
# Downloading marisa_trie-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.5 MB/s eta 0:00:00
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (pyproject.toml) ... rror
#   error: subprocess-exited-with-error
#
#   × Building wheel for cymem (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/about.py -> build/lib.linux-x86_64-cpython-38/cymem
#       creating build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/cymem.pyx -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/cymem.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       creating build/temp.linux-x86_64-cpython-38/cymem
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c cymem/cymem.cpp -o build/temp.linux-x86_64-cpython-38/cymem/cymem.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       cymem/cymem.cpp:33:10: fatal error: Python.h: No such file or directory
#          33 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cymem
#   Building wheel for murmurhash (pyproject.toml) ... rror
#   error: subprocess-exited-with-error
#
#   × Building wheel for murmurhash (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [30 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/about.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_hash.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/mrmr.pyx -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/mrmr.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash3.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash2.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       creating build/temp.linux-x86_64-cpython-38/murmurhash
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-do_34la8/murmurhash_6ff26c1aa6e649c7b842cf2841eddd43/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/MurmurHash2.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash2.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-do_34la8/murmurhash_6ff26c1aa6e649c7b842cf2841eddd43/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/MurmurHash3.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash3.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-do_34la8/murmurhash_6ff26c1aa6e649c7b842cf2841eddd43/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/mrmr.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/mrmr.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       murmurhash/mrmr.cpp:39:10: fatal error: Python.h: No such file or directory
#          39 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for murmurhash
# Failed to build cymem murmurhash
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (cymem, murmurhash)
# Note: you may need to restart the kernel to use updated packages.
# Collecting thinc==8.1.7
#   Downloading thinc-8.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc==8.1.7)
#   Using cached blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting murmurhash<1.1.0,>=1.0.2 (from thinc==8.1.7)
#   Using cached murmurhash-1.0.12.tar.gz (13 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cymem<2.1.0,>=2.0.2 (from thinc==8.1.7)
#   Using cached cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting preshed<3.1.0,>=3.0.2 (from thinc==8.1.7)
#   Using cached preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting wasabi<1.2.0,>=0.8.1 (from thinc==8.1.7)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.0 (from thinc==8.1.7)
#   Using cached srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.4 (from thinc==8.1.7)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc==8.1.7)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: setuptools in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from thinc==8.1.7) (75.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from thinc==8.1.7) (1.24.4)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from thinc==8.1.7)
#   Using cached pydantic-1.10.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (153 kB)
# Requirement already satisfied: packaging>=20.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from thinc==8.1.7) (24.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->thinc==8.1.7) (4.12.2)
# Downloading thinc-8.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.9/828.9 kB 9.5 MB/s eta 0:00:00
# Using cached blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
# Using cached pydantic-1.10.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Using cached srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for cymem (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/about.py -> build/lib.linux-x86_64-cpython-38/cymem
#       creating build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/cymem/tests
#       copying cymem/cymem.pyx -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/cymem.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       copying cymem/__init__.pxd -> build/lib.linux-x86_64-cpython-38/cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       creating build/temp.linux-x86_64-cpython-38/cymem
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c cymem/cymem.cpp -o build/temp.linux-x86_64-cpython-38/cymem/cymem.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       cymem/cymem.cpp:33:10: fatal error: Python.h: No such file or directory
#          33 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cymem
#   Building wheel for murmurhash (pyproject.toml) ... rror
#   error: subprocess-exited-with-error
#
#   × Building wheel for murmurhash (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [30 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/about.py -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/__init__.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_import.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/tests/test_hash.py -> build/lib.linux-x86_64-cpython-38/murmurhash/tests
#       copying murmurhash/mrmr.pyx -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/__init__.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       copying murmurhash/mrmr.pxd -> build/lib.linux-x86_64-cpython-38/murmurhash
#       creating build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash3.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       copying murmurhash/include/murmurhash/MurmurHash2.h -> build/lib.linux-x86_64-cpython-38/murmurhash/include/murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       creating build/temp.linux-x86_64-cpython-38/murmurhash
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-sgq2o2ad/murmurhash_ecd98b43dfa140e9a64676df417759aa/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/MurmurHash2.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash2.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-sgq2o2ad/murmurhash_ecd98b43dfa140e9a64676df417759aa/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/MurmurHash3.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/MurmurHash3.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer -fstack-protector-strong -fstack-clash-protection -Wformat -Werror=format-security -fcf-protection -g -fwrapv -O2 -fPIC -I/usr/include/python3.8 -I/tmp/pip-install-sgq2o2ad/murmurhash_ecd98b43dfa140e9a64676df417759aa/murmurhash/include -I/home/skumar/DaatScience/AutomatedTrading/.venv/include -I/usr/include/python3.8 -c murmurhash/mrmr.cpp -o build/temp.linux-x86_64-cpython-38/murmurhash/mrmr.o -O3 -Wno-strict-prototypes -Wno-unused-function
#       cc1plus: warning: command-line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#       murmurhash/mrmr.cpp:39:10: fatal error: Python.h: No such file or directory
#          39 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for murmurhash
# Failed to build cymem murmurhash
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (cymem, murmurhash)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pandas==2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pandas==2.0.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pandas==2.0.0) (2024.2)
# Requirement already satisfied: numpy>=1.20.3 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from pandas==2.0.0) (1.24.4)
# Requirement already satisfied: six>=1.5 in /home/skumar/DaatScience/AutomatedTrading/.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas==2.0.0) (1.16.0)
# Downloading pandas-2.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# Successfully installed pandas-2.0.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
